# %% [markdown]
# # Métodos autoregresivos para series de tiempo

# %%
#!pip3 install --upgrade statsmodels
# Out:
# Requirement already satisfied: statsmodels in d:\jasdata\python39\lib\site-packages (0.12.2)
# Requirement already satisfied: patsy>=0.5 in d:\jasdata\python39\lib\site-packages (from statsmodels) (0.5.1)
# Requirement already satisfied: numpy>=1.15 in d:\jasdata\python39\lib\site-packages (from statsmodels) (1.21.2)
# Requirement already satisfied: pandas>=0.21 in d:\jasdata\python39\lib\site-packages (from statsmodels) (1.2.3)
# Requirement already satisfied: scipy>=1.1 in d:\jasdata\python39\lib\site-packages (from statsmodels) (1.6.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in d:\jasdata\python39\lib\site-packages (from pandas>=0.21->statsmodels) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in d:\jasdata\python39\lib\site-packages (from pandas>=0.21->statsmodels) (2021.1)
# Requirement already satisfied: six in d:\jasdata\python39\lib\site-packages (from patsy>=0.5->statsmodels) (1.15.0)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importar el módulo estadístico para series de tiempo
import statsmodels

# %%
statsmodels.__version__
# Out:
# '0.12.2'

# %%
# Cargar los datos
url='https://raw.githubusercontent.com/JASDataCTG/Diplomado-ML/main/Modulo%209/Datasets/us_airline_carrier_passenger.csv'
df = pd.read_csv(url)
df.head()
# Out:
#         month  passengers
# 0  2000-01-01       46492
# 1  2000-02-01       48526
# 2  2000-03-01       58764
# 3  2000-04-01       56033
# 4  2000-05-01       58201

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   month       240 non-null    object
#  1   passengers  240 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 3.9+ KB

# %%
df['month'] = pd.to_datetime(df['month'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   month       240 non-null    datetime64[ns]
#  1   passengers  240 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 3.9 KB

# %%
# Visualizar la serie de datos
plt.figure(figsize=(20,6))
plt.plot(df['month'],df['passengers'],'o:', color='black')
# Out:
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %% [markdown]
# ## Crear los datos de entrenamiento y validación
# - Datos de entrenamiento: Fechas menores o iguales a Diciembre de 2016
# - Validación: Fechas posteriores a Diciembre de 2016

# %%
import datetime

# %%
df_train = df[df['month'] <= datetime.datetime.strptime('2016-12-01',"%Y-%m-%d")]
df_test = df[df['month'] > datetime.datetime.strptime('2016-12-01',"%Y-%m-%d")]

# %%
df_train.tail()
# Out:
#          month  passengers
# 199 2016-08-01       73450
# 200 2016-09-01       66477
# 201 2016-10-01       69539
# 202 2016-11-01       66591
# 203 2016-12-01       67983

# %%
df_test.head()
# Out:
#          month  passengers
# 204 2017-01-01       62621
# 205 2017-02-01       58377
# 206 2017-03-01       72962
# 207 2017-04-01       70262
# 208 2017-05-01       73679

# %%
plt.figure(figsize=(20,6))
plt.plot(df_train['month'],df_train['passengers'],'o:',alpha=0.5)
plt.plot(df_test['month'],df_test['passengers'],'o:',alpha=0.3)

plt.legend(['Train Data','Test Data'])
plt.ylabel('Passengers Count')
plt.grid()
plt.show()
# Out:
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %% [markdown]
# ### **ACF and PACF**
# La autocorrelación en series temporales es un término estadístico que se utiliza para describir la presencia o ausencia de correlación en los datos de las series temporales, indicando, si las observaciones pasadas influyen en las actuales.
#
# Por tanto, se puede decir que la autocorrelación hace referencia cuando los valores que toman una variable en el tiempo no son independientes entre sí, sino que un valor determinado depende de los valores anteriores.
#
# El problema de la autocorrelación se denomina también frecuentemente de “correlación serial”.
#
# Para medir la autocorrelación se suele usar:
#
# - La función de autocorrelación
# - La función de autocorrelación parcial
#
# **La función de autocorrelación (ACF)**
#
# Mide la correlación entre dos variables separadas por k periodos. Mide el grado de asociación lineal que existe entre dos variables del mismo proceso estocástico.
#
# **La función de autocorrelación parcial (PACF)**
#
# Mide la correlación entre dos variables separadas por k periodos cuando no se considera la dependencia creada por los retardos intermedios existentes entre ambas. Mide la autocorrelación que existe entre dos variables separadas k períodos descontando los posibles efectos debidos a variables intermedias.
#
# La función ACF es usada para identificar el proceso de media móvil (MA) en un modelo ARIMA; mientras que la función PACF se usa para identificar los valores de la parte del proceso autoregresivo (AR).
#
# Los gráficos generados a partir de estas funciones se denominan correlogramas, los cuales contienen bandas con un intervalo de confianza del 95%.

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
fig,ax = plt.subplots(nrows=1,ncols=2,figsize=(15,8))
res1 = plot_acf(df_train['passengers'],ax=ax[0])## primera celda ax[0]
plt.xlabel('Lags')
res2 = plot_pacf(df_train['passengers'],ax=ax[1])
plt.xlabel('Lags')
# Out:
# Text(0.5, 0, 'Lags')

# %% [markdown]
# La figura de autocorrelación nos indica

# %% [markdown]
# **Making Data Stationary**

# %%
difference = df_train['passengers'].diff()

# %%
plt.figure(figsize=(20,6))
plt.plot(df_train['month'],difference,'o:',alpha=0.5)

plt.legend(['Difference'])
plt.ylabel('Passengers Monthly Changes')
plt.grid()
plt.show()

# %%
difference.dropna(inplace=True) # drop the missing before computing ACF and PACF

# %%
fig,ax = plt.subplots(nrows=1,ncols=2,figsize=(15,8))
res1 = plot_acf(difference,ax=ax[0])
plt.xlabel('Lags')
res2 = plot_pacf(difference,ax=ax[1])
plt.xlabel('Lags')
# Out:
# Text(0.5, 0, 'Lags')

# %% [markdown]
# > **Clear Seasonality at 12 periods**

# %% [markdown]
# ## Auto Regressive Model
# - AR (p)
#
# p = number of lags
# - find p using PACF (find the number of lags which are not zero)
#
# - 12 lags from PACF
#
# AR(12)

# %%
x_train = df_train.set_index('month')
x_test = df_test.set_index('month')

# %%
from statsmodels.tsa.ar_model import AutoReg

# %%
model_ar = AutoReg(x_train,lags=12).fit()
# Out:
# /home/javier/.local/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# /home/javier/.local/lib/python3.8/site-packages/statsmodels/tsa/ar_model.py:248: FutureWarning: The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#   warnings.warn(

# %%
print(model_ar.summary())
# log likelilihood el error
# Out:
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:             passengers   No. Observations:                  204
# Model:                    AutoReg(12)   Log Likelihood               -1791.208
# Method:               Conditional MLE   S.D. of innovations           2725.128
# Date:                Tue, 28 Sep 2021   AIC                             15.966
# Time:                        18:07:54   BIC                             16.204
# Sample:                    01-01-2001   HQIC                            16.063
#                          - 12-01-2016
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# intercept      -1101.8877   2670.461     -0.413      0.680   -6335.894    4132.119
# passengers.L1      0.4234      0.062      6.848      0.000       0.302       0.545
# passengers.L2      0.0487      0.069      0.707      0.480      -0.086       0.184
# passengers.L3      0.1092      0.069      1.592      0.111      -0.025       0.244
# passengers.L4     -0.0769      0.069     -1.121      0.262      -0.211       0.058
# passengers.L5      0.0040      0.069      0.058      0.954      -0.131       0.139
# passengers.L6     -0.3615      0.065     -5.577      0.000      -0.489      -0.234
# passengers.L7      0.3415      0.064      5.324      0.000       0.216       0.467
# passengers.L8      0.0088      0.069      0.129      0.898      -0.126       0.144
# passengers.L9      0.1139      0.069      1.662      0.097      -0.020       0.248
# passengers.L10    -0.1056      0.069     -1.535      0.125      -0.240       0.029
# passengers.L11    -0.0069      0.070     -0.099      0.921      -0.144       0.130
# passengers.L12     0.5275      0.063      8.420      0.000       0.405       0.650
#                                     Roots
# ==============================================================================
#                    Real          Imaginary           Modulus         Frequency
# ------------------------------------------------------------------------------
# AR.1             0.9962           -0.0000j            0.9962           -0.0000
# AR.2             0.8809           -0.4933j            1.0096           -0.0812
# AR.3             0.8809           +0.4933j            1.0096            0.0812
# AR.4             0.6309           -0.8889j            1.0901           -0.1518
# AR.5             0.6309           +0.8889j            1.0901            0.1518
# AR.6             0.0077           -1.0137j            1.0137           -0.2488
# AR.7             0.0077           +1.0137j            1.0137            0.2488
# AR.8            -0.5200           -0.9730j            1.1032           -0.3281
# AR.9            -0.5200           +0.9730j            1.1032            0.3281
# AR.10           -0.8811           -0.5032j            1.0147           -0.4174
# AR.11           -0.8811           +0.5032j            1.0147            0.4174
# AR.12           -1.2201           -0.0000j            1.2201           -0.5000
# ------------------------------------------------------------------------------
# /home/javier/.local/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:132: FutureWarning: The 'freq' argument in Timestamp is deprecated and will be removed in a future version.
#   date_key = Timestamp(key, freq=base_index.freq)

# %%
# fitted values
fittedvalues = model_ar.fittedvalues

# %%
fittedvalues.head()
# Out:
# month
# 2001-01-01    49334.710929
# 2001-02-01    49964.903006
# 2001-03-01    57480.606603
# 2001-04-01    55642.948449
# 2001-05-01    57963.182409
# dtype: float64

# %%
plt.figure(figsize=(20,6))
plt.plot(df_train['month'],df_train['passengers'],'o:',alpha=0.5)
plt.plot(df_test['month'],df_test['passengers'],'o:',alpha=0.3)
# fitted values
plt.plot(fittedvalues,'g-')

plt.legend(['Train Data','Test Data','AR(12)'])
plt.ylabel('Passengers Count')
plt.grid()
plt.show()
# Out:
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
start = datetime.datetime.strptime('2017-01-01','%Y-%m-%d')
end = datetime.datetime.strptime('2019-12-01','%Y-%m-%d')
forecast_values = model_ar.predict(start,end)
# Out:
# /home/javier/.local/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:132: FutureWarning: The 'freq' argument in Timestamp is deprecated and will be removed in a future version.
#   date_key = Timestamp(key, freq=base_index.freq)
# /home/javier/.local/lib/python3.8/site-packages/statsmodels/tsa/deterministic.py:147: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Int64Indexes with a unit increment support extending. The index is set will contain the position relative to the data length.
#   warnings.warn(

# %%
forecast_values.head(3)
# Out:
# 2017-01-01    63865.557371
# 2017-02-01    63222.994100
# 2017-03-01    70781.913370
# Freq: MS, dtype: float64

# %%
ME = 1.96 * model_ar.resid.std()

# %%
plt.figure(figsize=(20,6))
plt.plot(df_train['month'],df_train['passengers'],'o:',alpha=0.5)
plt.plot(df_test['month'],df_test['passengers'],'o:',alpha=0.3)
# fitted values
plt.plot(fittedvalues,'g-')
# forecasted values
plt.plot(forecast_values,'r-')
# confidence
plt.fill_between(df_test['month'],(forecast_values.values+ME),((forecast_values.values-ME)),alpha=0.1)

plt.legend(['Train Data','Test Data','AR(12)','Forecast -AR(12)','Confidence Interval'])
plt.ylabel('Passengers Count')
plt.grid()
plt.show()
# Out:
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %% [markdown]
# **Evaluation**

# %%
fig = plt.figure(figsize=(15,6))
fig =model_ar.plot_diagnostics(lags=12,fig=fig)
